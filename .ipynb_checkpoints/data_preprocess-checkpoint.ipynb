# %%
import pandas as pd

# %%
https://flask.palletsprojects.com/en/2.1.x/patterns/flashing/
dialogs

# %%
# %run application.py
# Out:
#  * Serving Flask app 'application' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://172.20.2.147:5000/ (Press CTRL+C to quit)
# 172.20.2.147 - - [05/Jun/2022 06:04:41] "GET / HTTP/1.1" 200 -
# 172.20.2.147 - - [05/Jun/2022 06:04:41] "GET /static/css/bootstrap.min.css HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:04:41] "GET /crossorigin=%22anonymous%22 HTTP/1.1" 404 -
# 172.20.2.147 - - [05/Jun/2022 06:04:41] "GET /static/css/style.css HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:04:41] "GET /static/js/jquery.min.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:04:41] "GET /static/js/bootstrap.min.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:04:41] "GET /static/js/scripts.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:04:41] "GET /static/figure/Room_Type.png HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:04:41] "GET /static/figure/Correlation_Matrix.png HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:04:41] "GET /static/figure/Feature_Selection.png HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:04:41] "GET /static/figure/NYcity.jpg HTTP/1.1" 304 -
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1263">Loading BokehJS ...</span>
#     </div>
# 172.20.2.147 - - [05/Jun/2022 06:04:45] "GET /actual_app HTTP/1.1" 200 -
# 172.20.2.147 - - [05/Jun/2022 06:04:45] "GET /static/css/bootstrap.min.css HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:04:45] "GET /static/css/style.css HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:04:45] "GET /static/js/jquery.min.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:04:45] "GET /static/js/bootstrap.min.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:04:45] "GET /static/js/scripts.js HTTP/1.1" 304 -
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1577">Loading BokehJS ...</span>
#     </div>
# 172.20.2.147 - - [05/Jun/2022 06:04:54] "POST /actual_app HTTP/1.1" 200 -
# 172.20.2.147 - - [05/Jun/2022 06:04:54] "GET /static/css/bootstrap.min.css HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:04:54] "GET /static/css/style.css HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:04:54] "GET /static/js/jquery.min.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:04:54] "GET /static/js/bootstrap.min.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:04:54] "GET /static/js/scripts.js HTTP/1.1" 304 -
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1891">Loading BokehJS ...</span>
#     </div>
# 172.20.2.147 - - [05/Jun/2022 06:05:51] "POST /actual_app HTTP/1.1" 200 -
# 172.20.2.147 - - [05/Jun/2022 06:05:51] "GET /static/css/bootstrap.min.css HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:05:51] "GET /static/css/style.css HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:05:51] "GET /static/js/jquery.min.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:05:51] "GET /static/js/bootstrap.min.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:05:51] "GET /static/js/scripts.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:07:59] "GET / HTTP/1.1" 200 -
# 172.20.2.147 - - [05/Jun/2022 06:07:59] "GET /static/css/bootstrap.min.css HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:07:59] "GET /crossorigin=%22anonymous%22 HTTP/1.1" 404 -
# 172.20.2.147 - - [05/Jun/2022 06:07:59] "GET /static/css/style.css HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:07:59] "GET /static/js/jquery.min.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:07:59] "GET /static/js/bootstrap.min.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:07:59] "GET /static/js/scripts.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:07:59] "GET /static/figure/Room_Type.png HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:07:59] "GET /static/figure/Correlation_Matrix.png HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:07:59] "GET /static/figure/Feature_Selection.png HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:07:59] "GET /static/figure/NYcity.jpg HTTP/1.1" 304 -
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2205">Loading BokehJS ...</span>
#     </div>
# 172.20.2.147 - - [05/Jun/2022 06:08:03] "GET /actual_app HTTP/1.1" 200 -
# 172.20.2.147 - - [05/Jun/2022 06:08:03] "GET /static/css/bootstrap.min.css HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:03] "GET /static/css/style.css HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:03] "GET /static/js/jquery.min.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:03] "GET /static/js/bootstrap.min.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:03] "GET /static/js/scripts.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:06] "GET / HTTP/1.1" 200 -
# 172.20.2.147 - - [05/Jun/2022 06:08:06] "GET /static/css/bootstrap.min.css HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:06] "GET /crossorigin=%22anonymous%22 HTTP/1.1" 404 -
# 172.20.2.147 - - [05/Jun/2022 06:08:06] "GET /static/css/style.css HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:06] "GET /static/js/jquery.min.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:06] "GET /static/js/bootstrap.min.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:06] "GET /static/js/scripts.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:06] "GET /static/figure/Room_Type.png HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:06] "GET /static/figure/Correlation_Matrix.png HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:06] "GET /static/figure/Feature_Selection.png HTTP/1.1" 304 -
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2519">Loading BokehJS ...</span>
#     </div>
# 172.20.2.147 - - [05/Jun/2022 06:08:10] "GET /actual_app HTTP/1.1" 200 -
# 172.20.2.147 - - [05/Jun/2022 06:08:10] "GET /static/css/bootstrap.min.css HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:10] "GET /static/css/style.css HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:10] "GET /static/js/jquery.min.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:10] "GET /static/js/bootstrap.min.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:10] "GET /static/js/scripts.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:12] "GET / HTTP/1.1" 200 -
# 172.20.2.147 - - [05/Jun/2022 06:08:12] "GET /static/css/bootstrap.min.css HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:12] "GET /crossorigin=%22anonymous%22 HTTP/1.1" 404 -
# 172.20.2.147 - - [05/Jun/2022 06:08:12] "GET /static/css/style.css HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:12] "GET /static/js/jquery.min.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:12] "GET /static/js/bootstrap.min.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:12] "GET /static/js/scripts.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:12] "GET /static/figure/Room_Type.png HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:12] "GET /static/figure/Correlation_Matrix.png HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:12] "GET /static/figure/Feature_Selection.png HTTP/1.1" 304 -
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2833">Loading BokehJS ...</span>
#     </div>
# 172.20.2.147 - - [05/Jun/2022 06:08:16] "GET /actual_app HTTP/1.1" 200 -
# 172.20.2.147 - - [05/Jun/2022 06:08:16] "GET /static/css/bootstrap.min.css HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:16] "GET /static/css/style.css HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:16] "GET /static/js/jquery.min.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:16] "GET /static/js/bootstrap.min.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:16] "GET /static/js/scripts.js HTTP/1.1" 304 -
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3147">Loading BokehJS ...</span>
#     </div>
# 172.20.2.147 - - [05/Jun/2022 06:08:22] "POST /actual_app HTTP/1.1" 200 -
# 172.20.2.147 - - [05/Jun/2022 06:08:22] "GET /static/css/bootstrap.min.css HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:22] "GET /static/css/style.css HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:22] "GET /static/js/jquery.min.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:22] "GET /static/js/bootstrap.min.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:22] "GET /static/js/scripts.js HTTP/1.1" 304 -
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3461">Loading BokehJS ...</span>
#     </div>
# 172.20.2.147 - - [05/Jun/2022 06:08:28] "POST /actual_app HTTP/1.1" 200 -
# 172.20.2.147 - - [05/Jun/2022 06:08:29] "GET /static/css/bootstrap.min.css HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:29] "GET /static/css/style.css HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:29] "GET /static/js/jquery.min.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:29] "GET /static/js/bootstrap.min.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:29] "GET /static/js/scripts.js HTTP/1.1" 304 -
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3775">Loading BokehJS ...</span>
#     </div>
# 172.20.2.147 - - [05/Jun/2022 06:08:41] "POST /actual_app HTTP/1.1" 200 -
# 172.20.2.147 - - [05/Jun/2022 06:08:41] "GET /static/css/bootstrap.min.css HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:41] "GET /static/css/style.css HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:41] "GET /static/js/jquery.min.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:41] "GET /static/js/bootstrap.min.js HTTP/1.1" 304 -
# 172.20.2.147 - - [05/Jun/2022 06:08:41] "GET /static/js/scripts.js HTTP/1.1" 304 -

# %%
df = pd.read_csv('./data/AB_NYC_2019.csv')

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
# string to datetime
df['last_review'] = pd.to_datetime(df['last_review'])

# %%
# set NaN of last_review to earliest review time
earliest_time = df['last_review'].min()
df['last_review'][df['last_review'].isna()] = earliest_time
# Out:
# /tmp/ipykernel_2885/2655804918.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['last_review'][df['last_review'].isna()] = earliest_time

# %%
# add new col as timestamps of last_review time
df.insert(df.shape[1], 'last_review_ts', 0)
df['last_review_ts'] = df['last_review'].astype('int64')

# %%
# set NaN of reviews_per_month to 0
df['reviews_per_month'][df['reviews_per_month'].isna()] = 0
# Out:
# /tmp/ipykernel_2885/1341774583.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['reviews_per_month'][df['reviews_per_month'].isna()] = 0

# %%
# turn text names to indices
neighbor_dict = {}
neighbor_group_dict = {}
room_type_dict = {}

# %%
for i, name in enumerate(df.neighbourhood.value_counts().index):
    neighbor_dict[name] = i
for i, name in enumerate(df.neighbourhood_group.value_counts().index):
    neighbor_group_dict[name] = i
for i, name in enumerate(df.room_type.value_counts().index):
    room_type_dict[name] = i

# %%
for row in df.iterrows():
    i, row = row[0], row[1]
    neighborhood = row['neighbourhood']
    df.loc[i, 'neighbourhood'] = neighbor_dict[row['neighbourhood']]
    df.loc[i, 'neighbourhood_group'] = neighbor_group_dict[row['neighbourhood_group']]
    df.loc[i, 'room_type'] = room_type_dict[row['room_type']]

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'last_review_ts'],
#       dtype='object')

# %%
index = ['id', 'host_id', 'neighbourhood_group',
       'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
       'minimum_nights', 'number_of_reviews',
       'reviews_per_month', 'calculated_host_listings_count',
       'availability_365', 'last_review_ts']

# %%
df_new = df[index]
df_new.to_csv('./data/data_preprocessed.csv', index=False)
pd.read_csv('./data/data_preprocessed.csv')
# Out:
#              id   host_id  neighbourhood_group  neighbourhood  latitude  \
# 0          2539      2787                    1             52  40.64749
# 1          2595      2845                    0              9  40.75362
# 2          3647      4632                    0              2  40.80902
# 3          3831      4869                    1             19  40.68514
# 4          5022      7192                    0             10  40.79851
# ...         ...       ...                  ...            ...       ...
# 48890  36484665   8232441                    1              1  40.67853
# 48891  36485057   6570630                    1              3  40.70184
# 48892  36485431  23492952                    0              2  40.81475
# 48893  36485609  30985759                    0              5  40.75751
# 48894  36487245  68119814                    0              5  40.76404
#
#        longitude  room_type  price  minimum_nights  number_of_reviews  \
# 0      -73.97237          1    149               1                  9
# 1      -73.98377          0    225               1                 45
# 2      -73.94190          1    150               3                  0
# 3      -73.95976          0     89               1                270
# 4      -73.94399          0     80              10                  9
# ...          ...        ...    ...             ...                ...
# 48890  -73.94995          1     70               2                  0
# 48891  -73.93317          1     40               4                  0
# 48892  -73.94867          0    115              10                  0
# 48893  -73.99112          2     55               1                  0
# 48894  -73.98933          1     90               7                  0
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                   0.21                               6               365
# 1                   0.38                               2               355
# 2                   0.00                               1               365
# 3                   4.64                               1               194
# 4                   0.10                               1                 0
# ...                  ...                             ...               ...
# 48890               0.00                               2                 9
# 48891               0.00                               2                36
# 48892               0.00                               1                27
# 48893               0.00                               6                 2
# 48894               0.00                               1                23
#
#             last_review_ts
# 0      1539907200000000000
# 1      1558396800000000000
# 2      1301270400000000000
# 3      1562284800000000000
# 4      1542585600000000000
# ...                    ...
# 48890  1301270400000000000
# 48891  1301270400000000000
# 48892  1301270400000000000
# 48893  1301270400000000000
# 48894  1301270400000000000
#
# [48895 rows x 14 columns]
